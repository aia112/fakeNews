# %%
# Merge datasets
import pandas as pd

dreal = pd.read_csv("Titledataset.csv")
dfake = pd.read_csv("fakenewz.csv")

dreal
# Out:
#                                 Authors  \
# 0             ['Analysis John Harwood']
# 1                     ['Paul Gittings']
# 2                        ['Luke Mcgee']
# 3                                   NaN
# 4    ['Julia Horowitz', 'Cnn Business']
# ..                                  ...
# 691            ['Press Trust Of India']
# 692            ['Press Trust Of India']
# 693            ['Press Trust Of India']
# 694                     ['Bs Web Team']
# 695            ['Press Trust Of India']
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ..                                                 ...
# 691  Paper leak case: Supreme Court refuses to scra...
# ...

# %%
dreals = dreal[dreal.Category != "Africa"]
dreals = dreals[dreals.Category != "Asia"]
dreals = dreals[dreals.Category != "Middle-East"]
dreals = dreals[dreals.Category != "UK"]
dreals = dreals[dreals.Category != "US"]
dreals = dreals[dreals.Category != "Top Stories"]
dreals = dreals[dreals.Category != "Europe"]
dreals = dreals[dreals.Category != "Start Ups"]
dreals
# Out:
#                                 Authors  \
# 0             ['Analysis John Harwood']
# 1                     ['Paul Gittings']
# 2                        ['Luke Mcgee']
# 3                                   NaN
# 4    ['Julia Horowitz', 'Cnn Business']
# ..                                  ...
# 691            ['Press Trust Of India']
# 692            ['Press Trust Of India']
# 693            ['Press Trust Of India']
# 694                     ['Bs Web Team']
# 695            ['Press Trust Of India']
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ..                                                 ...
# 691  Paper leak case: Supreme Court refuses to scra...
# ...

# %%
set(dreals["Company"])d
# Out:
# {'BBC', 'Business Standard', 'CNN', 'NDTV', 'NY Times'}

# %%
set(dfake["Category"])
# Out:
# {'Entertainment', 'International News', 'Politics', 'Science', 'Sports'}

# %%
set(dreals["Category"])
# Out:
# {'Budget',
#  'Business',
#  'Climate',
#  'Education',
#  'Entertainment',
#  'General News',
#  'Health',
#  'International Market',
#  'Lifestyle',
#  'Markets',
#  'Movies',
#  'Politics',
#  'Space',
#  'Sports',
#  'Tech',
#  'Travel',
#  'World'}

# %%
dfake.drop("Unnamed: 7", axis=1, inplace = True)

# %%
dataset = pd.concat([dreals, dfake], ignore_index=True)
dataset
# Out:
#                                 Authors  \
# 0             ['Analysis John Harwood']
# 1                     ['Paul Gittings']
# 2                        ['Luke Mcgee']
# 3                                   NaN
# 4    ['Julia Horowitz', 'Cnn Business']
# ..                                  ...
# 925
# 926
# 927
# 928
# 929                                 NaN
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ..                                                 ...
# 925  Trump Ends North Korean Talks Early After Kim ...
# 926  Doctors Warn Drinking A Shot Every Time Trump ...
# 927  Trump Looking Forward To Knighthood From The Q...
# 928  Nation Wonders How Much More Fucking Evidence ...
# ...

# %%
dataset.to_csv("dataset.csv")

# %%
################### Removing spaces from Authors column ###############
df = pd.read_csv("dataset.csv", index_col = "Unnamed: 0")
df
# Out:
#                                 Authors  \
# 0             ['Analysis John Harwood']
# 1                     ['Paul Gittings']
# 2                        ['Luke Mcgee']
# 3                                   NaN
# 4    ['Julia Horowitz', 'Cnn Business']
# ..                                  ...
# 925
# 926
# 927
# 928
# 929                                 NaN
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ..                                                 ...
# 925  Trump Ends North Korean Talks Early After Kim ...
# 926  Doctors Warn Drinking A Shot Every Time Trump ...
# 927  Trump Looking Forward To Knighthood From The Q...
# 928  Nation Wonders How Much More Fucking Evidence ...
# ...

# %%
import numpy as np

# %%
df.replace({" ": np.nan}, inplace = True)

# %%
df.to_csv("temp.csv")

# %%
temp = pd.read_csv("temp.csv")

# %%
list(temp["Authors"].isnull()).count(False)
# Out:
# 594

# %%
list(df[df.Authors != " "]["Authors"].isnull()).count(False)
# Out:
# 594

# %%
set(df["Company"])
# Out:
# {'BBC',
#  'Business Standard',
#  'CNN',
#  'EmpireNews',
#  'NDTV',
#  'NY Times',
#  'babylonbee',
#  'burrardstreetjournal',
#  'dailyworldupdate',
#  'https://empirenews.net/breaking-war-with-iran-imminent-president-trump-reinstates-military-draft/',
#  'https://empirenews.net/jewish-reporter-asks-trump-if-he-plans-to-put-menorah-in-the-white-house-trump-tells-him-f-the-jews/',
#  'https://empirenews.net/michelle-obama-files-for-divorce-after-shocking-revelation-barack-obama-admits-im-gay/',
#  'https://empirenews.net/president-trump-backtracks-on-arming-teachers-idea-claims-he-forgot-there-were-black-teachers/',
#  'https://www.huzlers.com/new-scientific-study-suggest-marijuana-could-lead-to-homosexuality/',
#  'https://www.huzlers.com/teen-sues-juul-claims-vaping-made-him-homosexual/',
#  'https://www.thespoof.com/spoof-news/world/147115/putin-to-arrive-in-new-york-will-take-over-us',
#  'huzlers',
#  'infowars',
#  'nationalreport',
#  'now8news',
#  'realnewsrightnow',
# ...

# %%
list(df["Title"].isnull()).index(False)
# Out:
# 0

# %%
### Remove few fakenews
set(df["Label"])
# Out:
# {'FALSE', 'True'}

# %%
df = df[df.Label != "Politics"]
df = df[df.Label != "International News"]

# %%
df
# Out:
#                                 Authors  \
# 0             ['Analysis John Harwood']
# 1                     ['Paul Gittings']
# 2                        ['Luke Mcgee']
# 3                                   NaN
# 4    ['Julia Horowitz', 'Cnn Business']
# ..                                  ...
# 925                                 NaN
# 926                                 NaN
# 927                                 NaN
# 928                                 NaN
# 929                                 NaN
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ..                                                 ...
# 925  Trump Ends North Korean Talks Early After Kim ...
# ...

# %%
df.to_csv("dataset.csv")

# %%
df = pd.read_csv("dataset.csv", )
df
# Out:
#      Unnamed: 0                             Authors  \
# 0             0           ['Analysis John Harwood']
# 1             1                   ['Paul Gittings']
# 2             2                      ['Luke Mcgee']
# 3             3                                 NaN
# 4             4  ['Julia Horowitz', 'Cnn Business']
# ..          ...                                 ...
# 918         925                                 NaN
# 919         926                                 NaN
# 920         927                                 NaN
# 921         928                                 NaN
# 922         929                                 NaN
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ...

# %%
df.dropna(subset=["Text"], inplace = True)
df.dropna(subset=["Title"], inplace = True)
df = df[df.Category != "Movies"]
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#      Unnamed: 0                             Authors  \
# 0             0           ['Analysis John Harwood']
# 1             1                   ['Paul Gittings']
# 2             2                      ['Luke Mcgee']
# 3             3                                 NaN
# 4             4  ['Julia Horowitz', 'Cnn Business']
# ..          ...                                 ...
# 897         925                                 NaN
# 898         926                                 NaN
# 899         927                                 NaN
# 900         928                                 NaN
# 901         929                                 NaN
#
#                                                  Title  \
# 0         How Trump's presidency has played for Russia
# 1    Tokyo 2020 Olympics: Japanese PM Abe insists G...
# 2       Coronavirus is Boris Johnson's worst nightmare
# 3    She heard a woman yelling at the grocery store...
# 4    Here's what could really sink the global econo...
# ...
